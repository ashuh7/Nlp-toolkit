# %%
# !pip install nlpcloud
# Out:
# Requirement already satisfied: nlpcloud in c:\users\ashutosh\anaconda3\lib\site-packages (1.1.47)
# Requirement already satisfied: requests in c:\users\ashutosh\anaconda3\lib\site-packages (from nlpcloud) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ashutosh\anaconda3\lib\site-packages (from requests->nlpcloud) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashutosh\anaconda3\lib\site-packages (from requests->nlpcloud) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ashutosh\anaconda3\lib\site-packages (from requests->nlpcloud) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashutosh\anaconda3\lib\site-packages (from requests->nlpcloud) (2023.5.7)

# %%
class NLPApp:
    
    def __init__(self):
        
        self.__database = {}
        self.__first_menu()
    
    def __first_menu(self):
        
        first_input=input("""
        Hi! How would you like to proceed ->
        1. Not a member? Register
        2. Already a member? Login
        3. Not interested? Exit
        """)
        
        if first_input == '1':
            self.__register()
        elif first_input == '2':
            self.__login()
        else:
            exit() 
            
    def __register(self):
        print('register')
        name = input('Enter Name')
        email = input('Enter Email')
        password = input('Enter Password')
        
        if email in self.__database:
            print('Email already exists!')
        else:
            self.__database[email]=[name,password]
            print('Registration Successful; Now Login')
            print(self.__database)
            self.__login()
            
    def __login(self):
        print('login')
        

obj = NLPApp()
# Out:
#         Hi! How would you like to proceed ->
#         1. Not a member? Register
#         2. Already a member? Login
#         3. Not interested? Exit
#         1
# register
